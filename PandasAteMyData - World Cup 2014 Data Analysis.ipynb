# %% [markdown]
# ## Pandas Ate My Data - Python with Pandas
#
# Reference https://medium.com/carwow-product-engineering/sql-vs-pandas-how-to-balance-tasks-between-server-and-client-side-9e2f6c95677

# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 18.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 21.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
# !pip install -U matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.3/300.3 kB 4.6 MB/s eta 0:00:006.3 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 4.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 4.7 MB/s eta 0:00:00
# ...

# %%
# !pip install pandas-datareader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 1.5 MB/s eta 0:00:00 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.2 MB/s eta 0:00:00
# ...
#   Using cached charset_normalizer-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.2/123.2 kB 4.1 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 2.2 MB/s eta 0:00:000:00:010:00:01:01
# ...

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
from pandas_datareader import data
# %matplotlib inline

t3 = time.process_time()
csv3col = pd.read_csv("data/3col.csv")
elapsed_time3 = time.process_time() - t3
print(elapsed_time3/ 1000000.0)

t = time.process_time()
csv1col = pd.read_csv("data/1col.csv")
elapsed_time = time.process_time() - t
print(elapsed_time/ 1000000.0)
# Out:
# 5.628926830000003e-07
# 7.361353900000011e-08

# %%
squad = pd.read_csv("data/2014/squads.csv")

# %% [markdown]
# head(n)
# This function returns the first n rows for the object based on position. It is useful for quickly testing if your object has the right type of data in it.

# %%
squad.head(1)
# Out:
#    No  Pos         Player                               DOB/Age Caps
# 0  16  3MF  Aaron Clapham  (1987-01-01)1 January 1987 (aged 23)    0  \
#
#                 Club      Country  ClubCountry  Year
# 0  Canterbury United  New Zealand  New Zealand  2010

# %% [markdown]
# DataFrame.tail(n=5)[source]
# Return the last n rows.
#
# This function returns last n rows from the object based on position. It is useful for quickly verifying data, for example, after sorting or appending rows.

# %%
squad.tail()
# Out:
#       No  Pos              Player                                DOB/Age Caps
# 8892  18  3MF      Zvonimir Vukić     (1979-07-19)19 July 1979 (aged 26)   25  \
# 8893  10  3MF     Zvonko Živković  (1959-10-31)31 October 1959 (aged 22)  NaN
# 8894   3  1GK  Zygmunt Kalinowski       (1949-05-02)2 May 1949 (aged 25)    4
# 8895  21  1GK       Zygmunt Kukla  (1948-01-21)21 January 1948 (aged 30)  NaN
# 8896  14  3MF    Zygmunt Maszczyk       (1945-05-03)3 May 1945 (aged 29)   16
#
#                        Club                Country
# 8892  Shakhtar Donetsk [28]  Serbia and Montenegro  \
# 8893      Partizan Belgrade             Yugoslavia
# 8894          Śląsk Wrocław                 Poland
# 8895            Stal Mielec                 Poland
# 8896           Ruch Chorzów                 Poland
#
#                                    ClubCountry  Year
# 8892                                   Ukraine  2006
# 8893  Socialist Federal Republic of Yugoslavia  1982
# ...

# %% [markdown]
# Index is the numbering on the left side of the data frame

# %%
squad.index
# Out:
# RangeIndex(start=0, stop=8897, step=1)

# %%
df2 = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
df2.shape
# Out:
# (2, 2)

# %% [markdown]
# Columns are top header label/description of the rows of record

# %%
squad.columns
# Out:
# Index(['No', 'Pos', 'Player', 'DOB/Age', 'Caps', 'Club', 'Country',
#        'ClubCountry', 'Year'],
#       dtype='object')

# %%
squad.values
# Out:
# array([['16', '3MF', 'Aaron Clapham', ..., 'New Zealand', 'New Zealand',
#         2010],
#        ['13', '1GK', 'Aaron Lawrence', ..., 'Jamaica', 'Jamaica', 1998],
#        ['19', '3MF', 'Aaron Lennon', ..., 'England', 'England', 2006],
#        ...,
#        ['3', '1GK', 'Zygmunt Kalinowski', ..., '\xa0Poland', 'Poland',
#         1974],
#        ['21', '1GK', 'Zygmunt Kukla', ..., '\xa0Poland', 'Poland', 1978],
#        ['14', '3MF', 'Zygmunt Maszczyk', ..., '\xa0Poland', 'Poland',
#         1974]], dtype=object)

# %%
import pandas as pd

# Create a sample DataFrame
data = {'Name': ['John', 'Emily', 'Michael', 'Jessica'],
        'Age': [25, 30, 35, 28],
        'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}
df = pd.DataFrame(data)

# Get the dimensions of the DataFrame
print(df.shape)
# Out:
# (4, 3)

# %% [markdown]
# In the above example, the "df.shape" attribute returns a tuple (4, 3), indicating that the DataFrame has 4 rows and 3 columns.

# %% [markdown]
# Return a tuple representing the dimensionality of the DataFrame.

# %%
squad.shape
# Out:
# (8897, 9)

# %%
squad.dtypes
# Out:
# No             object
# Pos            object
# Player         object
# DOB/Age        object
# Caps           object
# Club           object
# Country        object
# ClubCountry    object
# Year            int64
# dtype: object

# %%
squad.info
# Out:
# <bound method DataFrame.info of       No  Pos              Player                                 DOB/Age
# 0     16  3MF       Aaron Clapham    (1987-01-01)1 January 1987 (aged 23)  \
# 1     13  1GK      Aaron Lawrence    (1970-08-11)11 August 1970 (aged 27)
# 2     19  3MF        Aaron Lennon     (1987-04-16)16 April 1987 (aged 19)
# 3      7  3MF        Aaron Lennon     (1987-04-16)16 April 1987 (aged 23)
# 4      4  2DF       Aaron Mokoena  (1980-11-25)25 November 1980 (aged 21)
# ...   ..  ...                 ...                                     ...
# 8892  18  3MF      Zvonimir Vukić      (1979-07-19)19 July 1979 (aged 26)
# 8893  10  3MF     Zvonko Živković   (1959-10-31)31 October 1959 (aged 22)
# 8894   3  1GK  Zygmunt Kalinowski        (1949-05-02)2 May 1949 (aged 25)
# 8895  21  1GK       Zygmunt Kukla   (1948-01-21)21 January 1948 (aged 30)
# 8896  14  3MF    Zygmunt Maszczyk        (1945-05-03)3 May 1945 (aged 29)
#
# ...

# %%
squad[squad.Country=='South Korea']
# Out:
#       No  Pos              Player                                  DOB/Age
# 1377   8  4FW      Choi Chung-Min     (1930-08-30)30 August 1930 (aged 23)  \
# 1395  18  4FW      Choi Yung-Keun    (1923-02-08)8 February 1923 (aged 31)
# 1442  16  3MF  Chu Yung-Kwang (c)       (1931-07-15)15 July 1931 (aged 22)
# 1447  20  4FW     Chung Kook-Chin     (1917-01-02)2 January 1917 (aged 37)
# 1449  11  3MF       Chung Nam-Sik   (1917-02-16)16 February 1917 (aged 37)
# 3178   -  3MF         Ha Dae-Sung       (1985-03-02)2 March 1985 (aged 29)
# 3192  12  1GK      Ham Heung-Chul   (1930-11-17)17 November 1930 (aged 23)
# 3208  14  2DF       Han Chang-Wha    (1922-11-03)3 November 1922 (aged 31)
# 3209   -  3MF      Han Kook-Young      (1990-04-19)19 April 1990 (aged 24)
# 3433   1  1GK     Hong Deok-Young         (1921-05-05)5 May 1921 (aged 33)
# 3434   -  2DF       Hong Jeong-Ho     (1989-08-12)12 August 1989 (aged 24)
# ...

# %%
koreanPlayers = squad[squad.Country=='South Korea']
koreanPlayers.count()
# Out:
# No             43
# Pos            43
# Player         43
# DOB/Age        43
# Caps           23
# Club           43
# Country        43
# ClubCountry    43
# Year           43
# dtype: int64

# %%
koreanPlayers.set_index(["Country", "Player", "Pos"]).count()
# Out:
# No             43
# DOB/Age        43
# Caps           23
# Club           43
# ClubCountry    43
# Year           43
# dtype: int64

# %% [markdown]
# In the example, the "set_index" method is used to set the "Country", "Player", "Pos" column as the index of the DataFrame.

# %%
worldcup = pd.read_csv("data/2014/worldcup.csv")
worldcup.head(3)
# Out:
#              name rounds__name  rounds__matches__num rounds__matches__date
# 0  World Cup 2014   Matchday 1                   1.0            2014-06-12  \
# 1  World Cup 2014   Matchday 1                   1.0            2014-06-12
# 2  World Cup 2014   Matchday 1                   1.0            2014-06-12
#
#   rounds__matches__time rounds__matches__team1__name
# 0                 17:00                       Brazil  \
# 1                 17:00                       Brazil
# 2                 17:00                       Brazil
#
#   rounds__matches__team1__code rounds__matches__team2__name
# 0                          BRA                      Croatia  \
# 1                          BRA                      Croatia
# 2                          BRA                      Croatia
#
#   rounds__matches__team2__code  rounds__matches__score1  ...
# 0                          CRO                      3.0  ...  \
# 1                          CRO                      NaN  ...
# ...

# %%
worldcup[["rounds__matches__team1__name", "rounds__matches__time"]].head(3)
# Out:
#   rounds__matches__team1__name rounds__matches__time
# 0                       Brazil                 17:00
# 1                       Brazil                 17:00
# 2                       Brazil                 17:00

# %%
dfScore = worldcup[["rounds__matches__team1__name", "rounds__matches__team2__name", "rounds__matches__score1", "rounds__matches__score2"]].tail()
dfScore.columns = ['Team 1', 'Team 2', 'Team 1 Goal' , 'Team 2 Goal']
dfScore
# Out:
#           Team 1       Team 2  Team 1 Goal  Team 2 Goal
# 133  Netherlands    Argentina          2.0          4.0
# 134       Brazil  Netherlands          0.0          3.0
# 135       Brazil  Netherlands          NaN          NaN
# 136       Brazil  Netherlands          NaN          NaN
# 137      Germany    Argentina          0.0          0.0

# %%
select = ["rounds__matches__team1__code", "rounds__matches__team2__code", "rounds__matches__goals1__penalty", "rounds__matches__goals2__penalty"]
df  = worldcup[select]
df.columns = ['Team 1', 'Team 2', 'Team 1 Goal Penalty' , 'Team 2 Goal Penalty']
df
# Out:
#     Team 1 Team 2 Team 1 Goal Penalty Team 2 Goal Penalty
# 0      BRA    CRO                 NaN                 NaN
# 1      BRA    CRO                True                 NaN
# 2      BRA    CRO                 NaN                 NaN
# 3      MEX    CMR                 NaN                 NaN
# 4      ESP    NED                True                 NaN
# ..     ...    ...                 ...                 ...
# 133    NED    ARG                 NaN                 NaN
# 134    BRA    NED                 NaN                True
# 135    BRA    NED                 NaN                 NaN
# 136    BRA    NED                 NaN                 NaN
# 137    GER    ARG                 NaN                 NaN
#
# [138 rows x 4 columns]

# %%
dfScore = worldcup[["rounds__matches__team1__name", "rounds__matches__team2__name", "rounds__matches__score1", "rounds__matches__score2"]].tail()
dfScore.columns = ['Team 1', 'Team 2', 'Team 1 Goal' , 'Team 2 Goal']
dfScore
# Out:
#           Team 1       Team 2  Team 1 Goal  Team 2 Goal
# 133  Netherlands    Argentina          2.0          4.0
# 134       Brazil  Netherlands          0.0          3.0
# 135       Brazil  Netherlands          NaN          NaN
# 136       Brazil  Netherlands          NaN          NaN
# 137      Germany    Argentina          0.0          0.0

# %%
dfScoreAddition = dfScore["Team 1 Goal"].add(5)
dfScoreAddition
# Out:
# 133    7.0
# 134    5.0
# 135    NaN
# 136    NaN
# 137    5.0
# Name: Team 1 Goal, dtype: float64

# %%
dfScoreSubtraction = dfScore["Team 2 Goal"] - 1
dfScoreSubtraction
# Out:
# 133    3.0
# 134    2.0
# 135    NaN
# 136    NaN
# 137   -1.0
# Name: Team 2 Goal, dtype: float64

# %%
dfScore
# Out:
#           Team 1       Team 2  Team 1 Goal  Team 2 Goal
# 133  Netherlands    Argentina          2.0          4.0
# 134       Brazil  Netherlands          0.0          3.0
# 135       Brazil  Netherlands          NaN          NaN
# 136       Brazil  Netherlands          NaN          NaN
# 137      Germany    Argentina          0.0          0.0

# %%
dfScoreMultiplication = dfScore["Team 1 Goal"] * 2
dfScoreMultiplication
# Out:
# 133    4.0
# 134    0.0
# 135    NaN
# 136    NaN
# 137    0.0
# Name: Team 1 Goal, dtype: float64

# %%
dfScoreDivision = dfScore["Team 1 Goal"] / 2
dfScoreDivision
# Out:
# 133    1.0
# 134    0.0
# 135    NaN
# 136    NaN
# 137    0.0
# Name: Team 1 Goal, dtype: float64

# %%
dfScore = worldcup[["rounds__matches__team1__name", "rounds__matches__team2__name", "rounds__matches__score1", "rounds__matches__score2"]].tail()
dfScore.columns = ['Team 1', 'Team 2', 'Team 1 Goal' , 'Team 2 Goal']
dfScore
# Out:
#           Team 1       Team 2  Team 1 Goal  Team 2 Goal
# 133  Netherlands    Argentina          2.0          4.0
# 134       Brazil  Netherlands          0.0          3.0
# 135       Brazil  Netherlands          NaN          NaN
# 136       Brazil  Netherlands          NaN          NaN
# 137      Germany    Argentina          0.0          0.0

# %%
dfScore["Team 1"].value_counts()
# Out:
# Team 1
# Brazil         3
# Netherlands    1
# Germany        1
# Name: count, dtype: int64

# %%
dfScore["Team 2"].value_counts().head(1)
# Out:
# Team 2
# Netherlands    3
# Name: count, dtype: int64

# %%
dfScore["Team 2"].value_counts().tail()
# Out:
# Team 2
# Netherlands    3
# Argentina      2
# Name: count, dtype: int64

# %%
dfScore.dropna(subset = ["Team 1 Goal", "Team 2 Goal"])
# Out:
#           Team 1       Team 2  Team 1 Goal  Team 2 Goal
# 133  Netherlands    Argentina          2.0          4.0
# 134       Brazil  Netherlands          0.0          3.0
# 137      Germany    Argentina          0.0          0.0

# %%
# describe the dataframe
dfScore.describe()
# Out:
#        Team 1 Goal  Team 2 Goal
# count     3.000000     3.000000
# mean      0.666667     2.333333
# std       1.154701     2.081666
# min       0.000000     0.000000
# 25%       0.000000     1.500000
# 50%       0.000000     3.000000
# 75%       1.000000     3.500000
# max       2.000000     4.000000

# %%
dfScore.sort_values('Team 2 Goal', ascending=False)
# Out:
#           Team 1       Team 2  Team 1 Goal  Team 2 Goal
# 133  Netherlands    Argentina          2.0          4.0
# 134       Brazil  Netherlands          0.0          3.0
# 137      Germany    Argentina          0.0          0.0
# 135       Brazil  Netherlands          NaN          NaN
# 136       Brazil  Netherlands          NaN          NaN

# %%
dfScore.sort_values(by='Team 1', ascending=True)
# Out:
#           Team 1       Team 2  Team 1 Goal  Team 2 Goal
# 134       Brazil  Netherlands          0.0          3.0
# 135       Brazil  Netherlands          NaN          NaN
# 136       Brazil  Netherlands          NaN          NaN
# 137      Germany    Argentina          0.0          0.0
# 133  Netherlands    Argentina          2.0          4.0

# %%
dfScore.sort_index(axis=1, ascending=True)
# Out:
#           Team 1  Team 1 Goal       Team 2  Team 2 Goal
# 133  Netherlands          2.0    Argentina          4.0
# 134       Brazil          0.0  Netherlands          3.0
# 135       Brazil          NaN  Netherlands          NaN
# 136       Brazil          NaN  Netherlands          NaN
# 137      Germany          0.0    Argentina          0.0

# %% [markdown]
# ## Series
#
# One-dimensional ndarray with axis labels (including time series).

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Rum Raisin"]

pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
lottery = [4, 8, 15, 16, 23, 42]

pd.Series(lottery)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
about_me = ["Smart", "Handsome", "Charming", "Brilliant", "Humble"]
s = pd.Series(about_me)
s
# Out:
# 0        Smart
# 1     Handsome
# 2     Charming
# 3    Brilliant
# 4       Humble
# dtype: object

# %%
s.values
# Out:
# array(['Smart', 'Handsome', 'Charming', 'Brilliant', 'Humble'],
#       dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.dtypes
# Out:
# dtype('O')

# %% [markdown]
# * 'b'       boolean
# * 'i'       (signed) integer
# * 'u'       unsigned integer
# * 'f'       floating-point
# * 'c'       complex-floating point
# * 'O'       (Python) objects
# * 'S', 'a'  (byte-)string
# * 'U'       Unicode
# * 'V'       raw data (void)

# %%
stadiums = pd.read_csv("data/2014/worldcup.stadiums.csv")
stadiums
# Out:
#               name       stadiums__key                     stadiums__name
# 0   World Cup 2014            maracana                Estádio do Maracanã  \
# 1   World Cup 2014  nacionaldebrasilia  Estádio Nacional (Mané Garrincha)
# 2   World Cup 2014         corinthians                  Arena Corinthians
# 3   World Cup 2014            castelao                   Estádio Castelão
# 4   World Cup 2014            mineirao                   Estádio Mineirão
# 5   World Cup 2014           fontenova                   Arena Fonte Nova
# 6   World Cup 2014            pantanal                     Arena Pantanal
# 7   World Cup 2014            amazonia                     Arena Amazônia
# 8   World Cup 2014            dasdunas                    Arena das Dunas
# 9   World Cup 2014            beirario                  Estádio Beira-Rio
# 10  World Cup 2014          pernambuco                   Arena Pernambuco
# 11  World Cup 2014           dabaixada                   Arena da Baixada
#
# ...

# %%
stadiums[0:4]
# Out:
#              name       stadiums__key                     stadiums__name
# 0  World Cup 2014            maracana                Estádio do Maracanã  \
# 1  World Cup 2014  nacionaldebrasilia  Estádio Nacional (Mané Garrincha)
# 2  World Cup 2014         corinthians                  Arena Corinthians
# 3  World Cup 2014            castelao                   Estádio Castelão
#
#    stadiums__capacity  stadiums__city stadiums__timezone
# 0               76935  Rio de Janeiro              UTC-3
# 1               70042        Brasília              UTC-3
# 2               68000       São Paulo              UTC-3
# 3               64846       Fortaleza              UTC-3

# %%
stadiums.loc[[]]
# Out:
# Empty DataFrame
# Columns: [name, stadiums__key, stadiums__name, stadiums__capacity, stadiums__city, stadiums__timezone]
# Index: []

# %%
stadiums.loc[:,['stadiums__name','stadiums__key']]
# Out:
#                        stadiums__name       stadiums__key
# 0                 Estádio do Maracanã            maracana
# 1   Estádio Nacional (Mané Garrincha)  nacionaldebrasilia
# 2                   Arena Corinthians         corinthians
# 3                    Estádio Castelão            castelao
# 4                    Estádio Mineirão            mineirao
# 5                    Arena Fonte Nova           fontenova
# 6                      Arena Pantanal            pantanal
# 7                      Arena Amazônia            amazonia
# 8                     Arena das Dunas            dasdunas
# 9                   Estádio Beira-Rio            beirario
# 10                   Arena Pernambuco          pernambuco
# 11                   Arena da Baixada           dabaixada

# %%
# Reduction in the dimensions of the returned object:
stadiums.loc[[9],['stadiums__capacity','stadiums__key']]
# Out:
#    stadiums__capacity stadiums__key
# 9               51300      beirario

# %%
stadiums.iloc[3]
# Out:
# name                    World Cup 2014
# stadiums__key                 castelao
# stadiums__name        Estádio Castelão
# stadiums__capacity               64846
# stadiums__city               Fortaleza
# stadiums__timezone               UTC-3
# Name: 3, dtype: object

# %%
stadiums.iloc[[1,2,4],[0,1,2,3]]
# Out:
#              name       stadiums__key                     stadiums__name
# 1  World Cup 2014  nacionaldebrasilia  Estádio Nacional (Mané Garrincha)  \
# 2  World Cup 2014         corinthians                  Arena Corinthians
# 4  World Cup 2014            mineirao                   Estádio Mineirão
#
#    stadiums__capacity
# 1               70042
# 2               68000
# 4               62547

# %%
stadiums.iloc[8,4]
# Out:
# 'Natal'

# %%
standings = pd.read_csv("data/2014/worldcup.standings.csv", index_col = "groups__name")
standings
# Out:
#                         name groups__standings__team__name
# groups__name
# Group A       World Cup 2014                        Brazil  \
# Group A       World Cup 2014                        Mexico
# Group A       World Cup 2014                       Croatia
# Group A       World Cup 2014                      Cameroon
# Group B       World Cup 2014                   Netherlands
# Group B       World Cup 2014                         Chile
# Group B       World Cup 2014                         Spain
# Group B       World Cup 2014                     Australia
# Group C       World Cup 2014                      Colombia
# Group C       World Cup 2014                        Greece
# Group C       World Cup 2014                 Côte d'Ivoire
# Group C       World Cup 2014                         Japan
# Group D       World Cup 2014                    Costa Rica
# Group D       World Cup 2014                       Uruguay
# Group D       World Cup 2014                         Italy
# ...

# %%
finalStandings = standings.groupby("groups__name")
standings.head(3)
# Out:
#                         name groups__standings__team__name
# groups__name
# Group A       World Cup 2014                        Brazil  \
# Group A       World Cup 2014                        Mexico
# Group A       World Cup 2014                       Croatia
#
#              groups__standings__team__code  groups__standings__pos
# groups__name
# Group A                                BRA                       1  \
# Group A                                MEX                       2
# Group A                                CRO                       3
#
#               groups__standings__played  groups__standings__won
# groups__name
# Group A                               3                       2  \
# Group A                               3                       2
# Group A                               3                       1
#
#               groups__standings__drawn  groups__standings__lost
# groups__name
# Group A                              1                        0  \
# ...

# %%
# Total group standing played on Group A
finalStandings.get_group("Group A")["groups__standings__played"].sum()
# Out:
# 12

# %%
teams = pd.read_csv("data/2014/worldcup.teams.csv")
teams
# Out:
#               name             Country teams__code teams__continent
# 0   World Cup 2014             Algeria         ALG           Africa  \
# 1   World Cup 2014       Côte d'Ivoire         CIV           Africa
# 2   World Cup 2014               Ghana         GHA           Africa
# 3   World Cup 2014             Nigeria         NGA           Africa
# 4   World Cup 2014            Cameroon         CMR           Africa
# 5   World Cup 2014               Japan         JPN             Asia
# 6   World Cup 2014         South Korea         KOR             Asia
# 7   World Cup 2014            Honduras         HON  Central America
# 8   World Cup 2014          Costa Rica         CRC  Central America
# 9   World Cup 2014             Belgium         BEL           Europe
# 10  World Cup 2014             Germany         GER           Europe
# 11  World Cup 2014               Spain         ESP           Europe
# 12  World Cup 2014              France         FRA           Europe
# ...

# %%
squad = pd.read_csv("data/2014/squads.csv")
squad
# Out:
#       No  Pos              Player                                 DOB/Age
# 0     16  3MF       Aaron Clapham    (1987-01-01)1 January 1987 (aged 23)  \
# 1     13  1GK      Aaron Lawrence    (1970-08-11)11 August 1970 (aged 27)
# 2     19  3MF        Aaron Lennon     (1987-04-16)16 April 1987 (aged 19)
# 3      7  3MF        Aaron Lennon     (1987-04-16)16 April 1987 (aged 23)
# 4      4  2DF       Aaron Mokoena  (1980-11-25)25 November 1980 (aged 21)
# ...   ..  ...                 ...                                     ...
# 8892  18  3MF      Zvonimir Vukić      (1979-07-19)19 July 1979 (aged 26)
# 8893  10  3MF     Zvonko Živković   (1959-10-31)31 October 1959 (aged 22)
# 8894   3  1GK  Zygmunt Kalinowski        (1949-05-02)2 May 1949 (aged 25)
# 8895  21  1GK       Zygmunt Kukla   (1948-01-21)21 January 1948 (aged 30)
# 8896  14  3MF    Zygmunt Maszczyk        (1945-05-03)3 May 1945 (aged 29)
#
#      Caps                   Club                Country
# ...

# %%
playersInWhichCountry = pd.merge(squad, teams, on='Country')
playersInWhichCountry
# Out:
#       No  Pos            Player                                 DOB/Age Caps
# 0     19  3MF      Aaron Lennon     (1987-04-16)16 April 1987 (aged 19)    1  \
# 1      7  3MF      Aaron Lennon     (1987-04-16)16 April 1987 (aged 23)   17
# 2      9  4FW  Alan Shearer (c)    (1970-08-13)13 August 1970 (aged 27)   39
# 3     16  3MF    Albert Quixall     (1933-08-09)9 August 1933 (aged 20)    3
# 4      -  2DF        Alf Ramsey   (1920-01-22)22 January 1920 (aged 30)    5
# ...   ..  ...               ...                                     ...  ...
# 3388   2  2DF    Park Kyu-Chung      (1924-06-12)12 June 1924 (aged 30)  NaN
# 3389   -  3MF     Son Heung-Min       (1992-07-08)8 July 1992 (aged 21)   23
# 3390  10  4FW     Sung Nak-Woon   (1926-02-02)2 February 1926 (aged 28)  NaN
# 3391   9  4FW     Woo Sang-Kwon   (1928-02-02)2 February 1928 (aged 26)  NaN
# 3392   -  2DF     Yun Suk-Young  (1990-02-13)13 February 1990 (aged 24)    2
#
# ...

# %%
# SELECT PlayerName WHERE COUNTRY='Algeria' LIMIT 12
brazildf = playersInWhichCountry[playersInWhichCountry['Country'] == 'Brazil'].sort_values(by='Player', ascending=True)

# %%
brazildf.to_excel('output/brazil.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('output/brazil.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#      No  Pos          Player                                  DOB/Age  Caps  \
# 488  14  2DF            Abel   (1952-09-01)1 September 1952 (aged 25)   1.0
# 489  12  1GK          Acácio    (1959-01-20)20 January 1959 (aged 31)   NaN
# 491   9  4FW          Ademir    (1922-11-08)8 November 1922 (aged 27)  25.0
# 492  18  3MF  Ademir da Guia       (1942-04-03)3 April 1942 (aged 32)   8.0
# 493  12  1GK             Ado        (1946-07-04)4 July 1946 (aged 23)   2.0
# 494   7  4FW         Adriano   (1982-02-17)17 February 1982 (aged 24)  32.0
# 490   -  4FW       Adãozinho       (1923-04-02)2 April 1923 (aged 27)   2.0
# 495   -  3MF       Afonsinho       (1914-03-08)8 March 1914 (aged 24)   NaN
# 496  18  4FW         Alcindo   (1945-12-16)16 December 1945 (aged 20)   NaN
# 498  13  2DF          Aldair   (1965-11-30)30 November 1965 (aged 28)   NaN
# 499   3  2DF          Aldair   (1965-11-30)30 November 1965 (aged 32)   NaN
# ...

# %% [markdown]
# ## Visualization
#
# Show a Pie Chart all the Brazilian's age group

# %%
#playersAge = '(1925-06-27)27 June 1925 (aged z)'
#playersAge = '(1925-06-27)27 June 1925 (aged 18)'
#playersAge = '(1925-06-27)27 June 1925 (aged 20)'
#playersAge = '(1925-06-27)27 June 1925 (aged 31)'

playersAge = ''

def representsInt(s):
    try: 
        int(s)
        return True
    except ValueError:
        return False

def determineAge(age_group):
    if age_group != '':
        if isinstance(age_group, str):
            arr = age_group.split('(aged ')
            arr2 = arr[1].split(')')
            if representsInt(arr2[0]) :
                realAge  = int(arr2[0])
                if realAge <= 19:
                    return "Young got potential"
                if realAge <= 30 and realAge > 19:
                    return "Career start here !"
                else:
                    return "Above 30 better score more before retirement !"

    
determineAge(playersAge)

# %%
plt.style.use("ggplot")

brazildf["DOB/Age"].apply(determineAge).value_counts().plot(kind = "pie", legend = True)
# Out:
# <Axes: ylabel='count'>

# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 1.2 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.8 MB/s eta 0:00:000:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 4.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 2.8 MB/s eta 0:00:003.0 MB/s eta 0:00:01
# ...

# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()

# %%
bb = pdr.get_data_yahoo("TSLA", start="2020-01-01", end="2023-01-01")
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000  \
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume
# Date
# ...

# %%
bb[["High", "Low"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google = pdr.get_data_yahoo("GOOGL", start="2020-01-01", end="2023-01-01")
print(google)
google.head(3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  67.420502  68.433998  67.324501  68.433998  68.433998  27278000
# 2020-01-03  67.400002  68.687500  67.365997  68.075996  68.075996  23408000
# 2020-01-06  67.581497  69.916000  67.550003  69.890503  69.890503  46768000
# 2020-01-07  70.023003  70.175003  69.578003  69.755501  69.755501  34330000
# 2020-01-08  69.740997  70.592499  69.631500  70.251999  70.251999  35314000
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  87.110001  89.550003  87.070000  89.230003  89.230003  23003000
# 2022-12-27  88.800003  88.940002  87.010002  87.389999  87.389999  20097300
# 2022-12-28  86.980003  88.040001  85.940002  86.019997  86.019997  19523200
# 2022-12-29  86.620003  88.849998  86.610001  88.449997  88.449997  23333500
# ...

# %%
def rank_performance(stock_price):
    if stock_price <= 69:
        return "Poor"
    elif stock_price > 20 and stock_price <= 30:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
plt.style.use("ggplot")
google["Close"].apply(rank_performance).value_counts().plot(kind = "barh")
# Out:
# <Axes: ylabel='Close'>

# %% [markdown]
# ## Exercise 1
#
# Find both player data of the soccer celebrities from Team Brazil (Ronadlo and Ronaldinho)
#
# <img src="https://images.performgroup.com/di/library/omnisport/32/85/ronaldo-cropped_1jm2feotxjjx41uxa4pnnu68q1.jpg" width="200px"></img><img src="https://i.insider.com/58766c06ee14b6c7148b7a07?width=813&format=jpeg" width="200px"></img>

# %% [markdown]
# ## Exercise 2
#
# Find which World Cup 2014 team didn't score a single goal

# %% [markdown]
# ## Exercise 3
#
# Select any of your favourite team, plot a bar chart of the player's age group. Y Axis is the counter and X axis is the age group. Example below:-
#
# <img src="https://www.researchgate.net/publication/324778586/figure/fig1/AS:619653659381763@1524748353791/A-bar-chart-showing-the-age-distribution-of-population.png" width="500px"></img>

# %% [markdown]
# Send me your solution via email <kenneth.phang@nus.edu.sg>
